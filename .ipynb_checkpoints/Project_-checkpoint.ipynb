# %%
from huggingface_hub import snapshot_download
import pandas as pd
import re
import regex
import string
import scipy as scp
import nltk
from gensim.test.utils import common_texts
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
lyrics_df = pd.read_csv('https://cdn-lfs.huggingface.co/datasets/juliensimon/autonlp-data-song-lyrics-demo/367571c0d07193ad0c8d577124d27076615bd98493fc1f5f785771496e673682')

# %%
lyrics_df
# Out:
#                                                    Lyric       Genre0
# 0      [Intro: Method Man w/ sample] + (Sunny valenti...      Hip Hop
# 1      [Sean Paul:]. Aye. It's Sean Paul 'long side. ...          Pop
# 2      Beauty finds refuge in herself. Lovers wrapped...        Indie
# 3      You've changed your tune. many times since we'...         Rock
# 4      I got all these J's rolled up. And got all the...      Hip Hop
# ...                                                  ...          ...
# 48488  Unforgettable face I can't think of her name. ...  Heavy Metal
# 48489  Shawty swing my way put that ass all in my fac...      Hip Hop
# 48490  Born in caught out. Care out fear in. Gear in ...         Rock
# 48491  I've got nothing to say today. I used my words...  Heavy Metal
# 48492  Going far Getting nowhere. Going far The way y...          Pop
#
# [48493 rows x 2 columns]

# %%
lyrics_n = re.sub("([\(\[]).*?([\)\]])", "", "[Intro: Method Man w/ sample] + (Sunny valentine). We got butter (8X). (The gun'll go the gun'll go.... The gun'll go...). [Raekwon]. Aiyo one thing for sure keep you of all. Keep a nice crib fly away keep to the point. Keep niggaz outta ya face who snakes. Keep bitches in they place keep the mac in a special place. Keep moving for papes keep cool keep doing what you doing. Keep it fly keep me in the crates. Cuz I will erase shit on the real note you'se a waste. It's right here for you I will lace you. Rip you and brace you put a nice W up on ya face. Word to mother you could get chased. It's nothing to taste blood on a thug if he gotta go. All I know is we be giving grace. This is a place from where we make tapes. We make 'em everywhere still in all we be making base. Y'all be making paste these little niggaz they be making shapes. Our shit is art yours is traced. [Chorus: Sunny Valentine]. This is the way that we rolling in the streets. You know when we roll we be packing that heat. The gun'll go the gun'll go the gun'll go the gun'll go. The gun'll go the gun'll go the gun'll go the gun'll go. The gun'll go the gun'll go.... [Method Man]. This is Poverty Island man these animals don't run. Slums where the ambulance don't come. Who got the best base? Fiends waiting to smoke some. Approach something ask him where he getting that coke from. My dudes hug blocks like samurai shogun. Cuz no V and no ones equalling no fun. Who want a treat they know huh? Body to go numb. My woman need funds plus her hair and her toes done. It is what it is though you fuck with the kid flow. That make it hard to get dough the harder to get gold. Harder the piff blow harder when it snow. The pinky and the wrist glow this here what we live for. Get gwop then get low but first thought. We gotta get the work off the gift and the curse boss. Yeah see I'm the shit yo the dirt in the fit no. Hustling from the get-go the motto is get more. [Chorus]. [Masta Killa]. We was quiet flashy brothers strapped all along. With the dirty .38 long twelve hour shift gate. Took case state to state you think he won't hold his weight?. Put ya money on the plate and watch it get scrapped. We get ape up in that club off that juice and Henn. And it's a no win situation fucking with them. You mean like Ewing at the front at the rim finger roll a Dutch. Million dollar stages touched techs gauges bust. Trust no one the lone shogun rugged Timb boot stomper. Damaging lyrical mass destruction launcher. Nothing can calm the quakeage when I break kid. Peace to my brothers up north doing state bids. [Chorus]. [Chorus 2: Sunny Valentine]. Whoa... this is the way we be rolling in the club. You know when we roll we be packing .32 snubs. The gun'll go the gun'll go the gun'll go the gun'll go. The gun'll go the gun'll go the gun'll go the gun'll go. The gun'll go the gun'll go the gun'll go the gun'll go. [Outro: sample to fade]. We got butter...")
lyrics_n3 = lyrics_n.translate(str.maketrans('', '', string.punctuation))
lyrics_n4 = re.sub(' +', ' ', lyrics_n3)

list_clipped = ['a', 'the', 'is', 'are']
new_list_song = []
for word in lyrics_n4.split():
    if word.lower() not in list_clipped:
        new_list_song.append(word)
new_song = " ".join(new_list_song)

new_song
#print(lyrics_n4)
# Out:
# 'We got butter Aiyo one thing for sure keep you of all Keep nice crib fly away keep to point Keep niggaz outta ya face who snakes Keep bitches in they place keep mac in special place Keep moving for papes keep cool keep doing what you doing Keep it fly keep me in crates Cuz I will erase shit on real note youse waste Its right here for you I will lace you Rip you and brace you put nice W up on ya face Word to mother you could get chased Its nothing to taste blood on thug if he gotta go All I know we be giving grace This place from where we make tapes We make em everywhere still in all we be making base Yall be making paste these little niggaz they be making shapes Our shit art yours traced This way that we rolling in streets You know when we roll we be packing that heat gunll go gunll go gunll go gunll go gunll go gunll go gunll go gunll go gunll go gunll go This Poverty Island man these animals dont run Slums where ambulance dont come Who got best base Fiends waiting to smoke some Approach something ask him where he getting that coke from My dudes hug blocks like samurai shogun Cuz no V and no ones equalling no fun Who want treat they know huh Body to go numb My woman need funds plus her hair and her toes done It what it though you fuck with kid flow That make it hard to get dough harder to get gold Harder piff blow harder when it snow pinky and wrist glow this here what we live for Get gwop then get low but first thought We gotta get work off gift and curse boss Yeah see Im shit yo dirt in fit no Hustling from getgo motto get more We was quiet flashy brothers strapped all along With dirty 38 long twelve hour shift gate Took case state to state you think he wont hold his weight Put ya money on plate and watch it get scrapped We get ape up in that club off that juice and Henn And its no win situation fucking with them You mean like Ewing at front at rim finger roll Dutch Million dollar stages touched techs gauges bust Trust no one lone shogun rugged Timb boot stomper Damaging lyrical mass destruction launcher Nothing can calm quakeage when I break kid Peace to my brothers up north doing state bids Whoa this way we be rolling in club You know when we roll we be packing 32 snubs gunll go gunll go gunll go gunll go gunll go gunll go gunll go gunll go gunll go gunll go gunll go gunll go We got butter'

# %%
new_lyrics = []

for lyrics in lyrics_df['Lyric'].tolist():
    
    lyrics_n = re.sub("([\(\[]).*?([\)\]])", "", lyrics)
    lyrics_n2 = lyrics_n.translate(str.maketrans('', '', string.punctuation))
    lyrics_n3 = re.sub(' +', ' ', lyrics_n2)
    lyrics_n4 = re.sub(r'[0-9]+', '', lyrics_n3)
    
    list_clipped = ['a', 'the', 'is', 'are']
    new_list_song = []
    for word in lyrics_n4.split():
        if word.lower() not in list_clipped:
            new_list_song.append(word)
            new_song = " ".join(new_list_song)
    
    new_lyrics.append(new_song)
    
lyrics_df['Lyric'] = new_lyrics

# %%
lyrics_df
# Out:
#                                                    Lyric       Genre0
# 0      We got butter Aiyo one thing for sure keep you...      Hip Hop
# 1      Aye Its Sean Paul long side mandem called Jay ...          Pop
# 2      Beauty finds refuge in herself Lovers wrapped ...        Indie
# 3      Youve changed your tune many times since weve ...         Rock
# 4      I got all these Js rolled up And got all these...      Hip Hop
# ...                                                  ...          ...
# 48488  Unforgettable face I cant think of her name It...  Heavy Metal
# 48489  Shawty swing my way put that ass all in my fac...      Hip Hop
# 48490  Born in caught out Care out fear in Gear in he...         Rock
# 48491  Ive got nothing to say today I used my words u...  Heavy Metal
# 48492  Going far Getting nowhere Going far way you Go...          Pop
#
# [48493 rows x 2 columns]

# %%
lyr = lyrics_df['Lyric'].tolist()
tfidf_ = TfidfTransformer(use_idf=True)
v = TfidfVectorizer()
x = v.fit_transform(lyr)
feat_list = v.get_feature_names()
#wordcount = countVectorizer.fit_transform(dataset)
#newTfIdf = tfIdfTransformer.fit_transform(wordCount)
#df = pd.DataFrame(newTfIdf[0].T.todense(), index=countVectorizer.get_feature_names(), columns=["TF-IDF"])
#df = df.sort_values('TF-IDF', ascending=False)
print(feat_list)
# Out:
# ['aa', 'aaa', 'aaaa', 'aaaaa', 'aaaaaa', 'aaaaaaa', 'aaaaaaaa', 'aaaaaaaaa', 'aaaaaaaaaaa', 'aaaaaaaaaaaaaaa', 'aaaaaaaaaaaaaaaaaaaaaaaaaaah', 'aaaaaaaaaaaaaaaaaaah', 'aaaaaaaaaaaaaaaahhh', 'aaaaaaaaaaaaaaahhhh', 'aaaaaaaaaaaah', 'aaaaaaaaaaaahhhhhhhhhhhhh', 'aaaaaaaaaaaal', 'aaaaaaaaaaah', 'aaaaaaaaaah', 'aaaaaaaaaahhh', 'aaaaaaaaaahhhhhhhhh', 'aaaaaaaaaaoooow', 'aaaaaaaaah', 'aaaaaaaah', 'aaaaaaaahaaah', 'aaaaaaaahh', 'aaaaaaaahhh', 'aaaaaaaawwwooooooowwwaaaaaaaooo', 'aaaaaaah', 'aaaaaaahhhhhhhhhhhhh', 'aaaaaaahhhhhhhhhiiiiiii', 'aaaaaah', 'aaaaaahhh', 'aaaaaaoh', 'aaaaah', 'aaaaahh', 'aaaaahhh', 'aaaaahhhhh', 'aaaaair', 'aaaaall', 'aaaaass', 'aaaaggggaaiinnn', 'aaaagh', 'aaaah', 'aaaahh', 'aaaahhh', 'aaaahhhh', 'aaaahhhhh', 'aaaahhhhhh', 'aaaall', 'aaaam', 'aaaapplause', 'aaaat', 'aaaaw', 'aaaayeh', 'aaaayowwww', 'aaachew', 'aaagain', 'aaah', 'aaahaaaah', 'aaahahahahahaaahahahah', 'aaahh', 'aaahhh', 'aaahhhh', 'aaahhhhh', 'aaahhn', 'aaahs', 'aaall', 'aaand', 'aaaooooiii', 'aaare', 'aaarmani', 'aaarthur', 'aaask', 'aaass', 'aaasthma', 'aaaww', 'aaawwww', 'aaawwwww', 'aaawwwwww', 'aaay', 'aaayye', 'aabout', 'aacting', 'aad', 'aadios', 'aaeyey', 'aafes', 'aafreenetcarletonca', 'aaga', 'aah', 'aahaahaahaha', 'aahah', 'aahahahah', 'aahh', 'aahhaa', 'aahhh', 'aahhha', 'aahhhh', 'aahhhhh', 'aahhhhhhh', 'aahnaiad', 'aahoo', 'aahpromises', 'aahs', 'aaint', 'aair', 'aaj', 'aaja',